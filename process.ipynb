# %%
import pandas as pd
df = pd.read_csv("train.csv")
df
# Out:
#                                                image_link  group_id  \
# 0       https://m.media-amazon.com/images/I/61I9XdN6OF...    748919
# 1       https://m.media-amazon.com/images/I/71gSRbyXmo...    916768
# 2       https://m.media-amazon.com/images/I/61BZ4zrjZX...    459516
# 3       https://m.media-amazon.com/images/I/612mrlqiI4...    459516
# 4       https://m.media-amazon.com/images/I/617Tl40LOX...    731432
# ...                                                   ...       ...
# 263854  https://m.media-amazon.com/images/I/612J1R1xHl...    558806
# 263855  https://m.media-amazon.com/images/I/61Blzh2+28...    470067
# 263856  https://m.media-amazon.com/images/I/51MsegDL9V...    204245
# 263857  https://m.media-amazon.com/images/I/510KhVw4VS...    752266
# 263858  https://m.media-amazon.com/images/I/51lzTNLQ-6...    416664
#
#         entity_name     entity_value
# 0       item_weight       500.0 gram
# 1       item_volume          1.0 cup
# ...

# %%
dfs = {category: df[df['group_id'] == category] for category in df['group_id'].unique()}
# Sort the DataFrames by number of rows in descending order
sorted_dfs = sorted(dfs.items(), key=lambda x: len(x[1]), reverse=True)

# Get the top 10 (or fewer) DataFrames
top_10_dfs = sorted_dfs[:10]

# %%
for key, value in top_10_dfs:
    print(f"\nDataFrame for Category '{key}' (Rows: {len(value)}):")
# Out:
# DataFrame for Category '459516' (Rows: 9458):
#
# DataFrame for Category '752266' (Rows: 9063):
#
# DataFrame for Category '281678' (Rows: 6137):
#
# DataFrame for Category '308856' (Rows: 5437):
#
# DataFrame for Category '731432' (Rows: 4741):
#
# DataFrame for Category '630869' (Rows: 4671):
#
# DataFrame for Category '299791' (Rows: 4590):
#
# DataFrame for Category '993359' (Rows: 4588):
#
# DataFrame for Category '675317' (Rows: 4525):
#
# DataFrame for Category '483370' (Rows: 3442):

# %%
df459516 = dfs[459516]

# %%
df459516.iloc[0, 0]
# Out:
# 'https://m.media-amazon.com/images/I/61BZ4zrjZXL.jpg'

# %%
import IPython
url = df459516.iloc[0, 0]
IPython.display.Image(url, width = 250)

# %%
import IPython
import requests
from PIL import Image
import numpy as np
from io import BytesIO

# URL of the image
url = df459516.iloc[0, 0]

# Display the image
IPython.display.display(IPython.display.Image(url, width=250))

# Load the image from the URL
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# Convert the image to grayscale
img_gray = img.convert('L')  # 'L' mode converts to grayscale

# Convert the grayscale image to a numpy array
pixel_array = np.array(img_gray)

# Display the pixel array
print(pixel_array)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
